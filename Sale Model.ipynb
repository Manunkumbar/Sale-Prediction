# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Advertising_data.csv')
data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   2210
# 1   44.5   39.3       45.1   1040
# 2   17.2   45.9       69.3    930
# 3  151.5   41.3       58.5   1850
# 4  180.8   10.8       58.4   1290

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 6.4 KB

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
data = data.dropna()

# %%
# train test split
X = data[["TV","radio","newspaper"]]
Y = data["sales"]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predicted = model.predict(x_test)
predicted
# Out:
# array([1005.73956321,  745.22806954,  701.97075952, 2408.02972481,
#        1201.78625892,  653.79385757, 1278.28691771, 1510.9745874 ,
#        1076.97401318, 1634.35795135, 2288.29747665,  912.92446709,
#        1046.4556719 , 1548.74355219, 1158.55563328, 1217.29691362,
#        1876.55150183, 1078.31856605, 1590.51599168, 1730.65127862,
#        2406.69205718,  959.83422424, 1513.51221066, 1238.5915255 ,
#         571.3608846 , 1524.74931357, 1229.40233378, 2094.21167015,
#        1340.99155812,  904.34883229, 1289.23941508, 2140.27202807,
#        1813.80220856, 2117.3208027 ,  656.97443256,  614.11420628,
#         789.01839419, 1301.54143405, 1468.95379089,  618.83514289])

# %%
#MSE value
MSE = ((y_test-predicted)**2).mean()
MSE
# Out:
# 44021.182914496865

# %%
RMSE = MSE**0.5
RMSE
# Out:
# 209.81225634956806

# %%
MAE = (np.abs(y_test-predicted)).mean()
MAE
# Out:
# 136.17813502090286

# %%
import pickle

# %%
f = open("sales_model.sav","wb")
pickle.dump(model,f)
f.close()
